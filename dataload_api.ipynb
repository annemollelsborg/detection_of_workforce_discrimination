# %% [markdown]
# # Data load
# Data is collected from OECD database: https://gitlab.algobank.oecd.org/public-documentation/dotstat-migration/-/raw/main/OECD_Data_API_documentation.pdf
# ## Documentation
#
# - Wage gap: https://data-explorer.oecd.org/vis?lc=en&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_EARNINGS%40AGE_WAGE_GAP&df[ag]=OECD.ELS.SAE&df[vs]=1.0&dq=.S_PA_WP....MEAN._T&pd=2000%2C&to[TIME_PERIOD]=false
# - SIGI: https://data-explorer.oecd.org/vis?tm=DF_SIGI_2023&pg=0&snb=1&vw=tb&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_SIGI%40DF_SIGI_2023&df[ag]=OECD.DEV.NPG&df[vs]=&lo=5&lom=LASTNPERIODS&dq=..&ly[rw]=REF_AREA&ly[cl]=MEASURE&to[TIME_PERIOD]=false
# - Representation: https://data-explorer.oecd.org/vis?lc=en&pg=0&snb=1&vw=ov&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_GOV%40DF_GOV_EMPPS_REP_2023&df[ag]=OECD.GOV.GIP&df[vs]=&pd=2007%2C&dq=A.AUT.....&ly[rw]=MEASURE%2CSECTOR%2CUNIT_MEASURE&ly[cl]=TIME_PERIOD&to[TIME_PERIOD]=false

# %%
import pandas as pd
import requests
from io import StringIO

# Define a User-Agent header to avoid 403 errors
headers = {
    'User-Agent': 'Mozilla/5.0'
}

# Define URLs for the datasets
datasets = {
    "wage_gap": "https://sdmx.oecd.org/public/rest/data/OECD.ELS.SAE,DSD_EARNINGS@GENDER_WAGE_GAP,/......_T?startPeriod=2005&dimensionAtObservation=AllDimensions&format=csvfilewithlabels",
    "SIGI": "https://sdmx.oecd.org/public/rest/data/OECD.DEV.NPG,DSD_SIGI@DF_SIGI_2023,/all?startPeriod=2019&dimensionAtObservation=AllDimensions&format=csvfilewithlabels",
    "representation": "https://sdmx.oecd.org/public/rest/data/OECD.GOV.GIP,DSD_GOV@DF_GOV_EMPPS_REP_2023,/A.AUT.....?startPeriod=2007&dimensionAtObservation=AllDimensions&format=csvfilewithlabels"
}

# Dictionary to store the loaded dataframes
dataframes = {}

# Loop through the datasets and load them
for name, url in datasets.items():
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        dataframes[name] = pd.read_csv(StringIO(response.text))
        print(f"Loaded dataset: {name}")
        print(dataframes[name].head())
    else:
        print(f"Failed to retrieve data for {name}: {response.status_code}")
# Out:
# Loaded dataset: wage_gap
#   STRUCTURE                                    STRUCTURE_ID   STRUCTURE_NAME  \
# 0  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)  Gender wage gap
# 1  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)  Gender wage gap
# 2  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)  Gender wage gap
# 3  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)  Gender wage gap
# 4  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)  Gender wage gap
#
#   ACTION REF_AREA Reference area MEASURE          Measure   UNIT_MEASURE  \
# 0      I      IND          India     GWP  Gender wage gap  PT_WG_SAL_M_D
# 1      I      IND          India     GWP  Gender wage gap  PT_WG_SAL_M_D
# 2      I      AUS      Australia     GWP  Gender wage gap  PT_WG_SAL_M_D
# 3      I      AUS      Australia     GWP  Gender wage gap  PT_WG_SAL_M_D
# 4      I      AUS      Australia     GWP  Gender wage gap  PT_WG_SAL_M_D
#
#                                  Unit of measure  ...  OBS_VALUE  \
# 0  Percentage of wages of men in the same decile  ...   4.761905
# 1  Percentage of wages of men in the same decile  ...  12.500000
# 2  Percentage of wages of men in the same decile  ...  15.966387
# 3  Percentage of wages of men in the same decile  ...  14.042934
# 4  Percentage of wages of men in the same decile  ...  16.363636
#
#   Observation value BASE_PER Base period OBS_STATUS Observation status  \
# 0               NaN      NaN         NaN          A       Normal value
# 1               NaN      NaN         NaN          A       Normal value
# 2               NaN      NaN         NaN          A       Normal value
# 3               NaN      NaN         NaN          A       Normal value
# 4               NaN      NaN         NaN          A       Normal value
#
#   UNIT_MULT Unit multiplier  DECIMALS  Decimals
# 0         0           Units         1       One
# 1         0           Units         1       One
# 2         0           Units         1       One
# 3         0           Units         1       One
# 4         0           Units         1       One
#
# [5 rows x 30 columns]
# Loaded dataset: SIGI
#   STRUCTURE                             STRUCTURE_ID  \
# 0  DATAFLOW  OECD.DEV.NPG:DSD_SIGI@DF_SIGI_2023(1.0)
# 1  DATAFLOW  OECD.DEV.NPG:DSD_SIGI@DF_SIGI_2023(1.0)
# 2  DATAFLOW  OECD.DEV.NPG:DSD_SIGI@DF_SIGI_2023(1.0)
# 3  DATAFLOW  OECD.DEV.NPG:DSD_SIGI@DF_SIGI_2023(1.0)
# 4  DATAFLOW  OECD.DEV.NPG:DSD_SIGI@DF_SIGI_2023(1.0)
#
#                                      STRUCTURE_NAME ACTION REF_AREA  \
# 0  Social Institutions and Gender Index (SIGI) 2023      I      AUT
# 1  Social Institutions and Gender Index (SIGI) 2023      I      CHL
# 2  Social Institutions and Gender Index (SIGI) 2023      I      CZE
# 3  Social Institutions and Gender Index (SIGI) 2023      I      FRA
# 4  Social Institutions and Gender Index (SIGI) 2023      I      DEU
#
#   Reference area   MEASURE                        Measure UNIT_MEASURE  \
# 0        Austria      SIGI                     SIGI score     0_TO_100
# 1          Chile  SIGI_RPI  Restricted physical integrity     0_TO_100
# 2        Czechia  SIGI_RCL     Restricted civil liberties     0_TO_100
# 3         France   SIGI_DF   Discrimination in the family     0_TO_100
# 4        Germany      SIGI                     SIGI score     0_TO_100
#
#   Unit of measure  TIME_PERIOD  Time period  OBS_VALUE  Observation value  \
# 0     0-100 scale         2023          NaN        9.8                NaN
# 1     0-100 scale         2023          NaN       22.7                NaN
# 2     0-100 scale         2023          NaN       21.0                NaN
# 3     0-100 scale         2023          NaN        8.1                NaN
# 4     0-100 scale         2023          NaN       12.4                NaN
#
#   OBS_STATUS Observation status
# 0          A       Normal value
# 1          A       Normal value
# 2          A       Normal value
# 3          A       Normal value
# 4          A       Normal value
# Loaded dataset: representation
#   STRUCTURE                                     STRUCTURE_ID  \
# 0  DATAFLOW  OECD.GOV.GIP:DSD_GOV@DF_GOV_EMPPS_REP_2023(1.0)
# 1  DATAFLOW  OECD.GOV.GIP:DSD_GOV@DF_GOV_EMPPS_REP_2023(1.0)
# 2  DATAFLOW  OECD.GOV.GIP:DSD_GOV@DF_GOV_EMPPS_REP_2023(1.0)
# 3  DATAFLOW  OECD.GOV.GIP:DSD_GOV@DF_GOV_EMPPS_REP_2023(1.0)
# 4  DATAFLOW  OECD.GOV.GIP:DSD_GOV@DF_GOV_EMPPS_REP_2023(1.0)
#
#                                       STRUCTURE_NAME ACTION FREQ  \
# 0  Public employment and representation - Governm...      I    A
# 1  Public employment and representation - Governm...      I    A
# 2  Public employment and representation - Governm...      I    A
# 3  Public employment and representation - Governm...      I    A
# 4  Public employment and representation - Governm...      I    A
#
#   Frequency of observation REF_AREA Reference area    MEASURE  \
# 0                   Annual      AUT        Austria     EMPWPS
# 1                   Annual      AUT        Austria     EMPWPS
# 2                   Annual      AUT        Austria   EMPW_CFI
# 3                   Annual      AUT        Austria  EMPW_CMIN
# 4                   Annual      AUT        Austria   EMPW_SMP
#
#                                              Measure  ... OBS_VALUE  \
# 0        Gender equality in public sector employment  ...     41.77
# 1        Gender equality in public sector employment  ...     38.93
# 2        Gender equality in courts of first instance  ...     53.00
# 3   Gender equality in cabinet ministerial positions  ...     25.00
# 4  Gender equality in senior management positions...  ...     37.70
#
#   Observation value OBS_STATUS Observation status  UNIT_MULT  Unit multiplier  \
# 0               NaN          A       Normal value          0            Units
# 1               NaN          A       Normal value          0            Units
# 2               NaN          A       Normal value          0            Units
# 3               NaN          A       Normal value          0            Units
# 4               NaN          A       Normal value          0            Units
#
#   PRICE_BASE      Price base  BASE_PER  Base period
# 0         _Z  Not applicable       NaN          NaN
# 1         _Z  Not applicable       NaN          NaN
# 2         _Z  Not applicable       NaN          NaN
# 3         _Z  Not applicable       NaN          NaN
# 4         _Z  Not applicable       NaN          NaN
#
# [5 rows x 30 columns]

# %%
for name, df in dataframes.items():
    print(f"Dimensions of {name}: {df.shape}")
# Out:
# Dimensions of wage_gap: (1834, 30)
# Dimensions of SIGI: (940, 16)
# Dimensions of representation: (69, 30)

# %%
import os

# Save the datasets as CSV files in the subfolder "CSVfiles"

# Create the subfolder if it doesn't exist
os.makedirs("CSVfiles", exist_ok=True)
for name, df in dataframes.items():
    df.to_csv(f"CSVfiles/{name}.csv", index=False)
    print(f"Saved {name} to CSVfiles/{name}.csv")
# Example of how to access a specific dataframe
# wage_gap_df = dataframes["wage_gap"]
# wage_gap_df.head()
# Out:
# Saved wage_gap to CSVfiles/wage_gap.csv
# Saved SIGI to CSVfiles/SIGI.csv
# Saved representation to CSVfiles/representation.csv
